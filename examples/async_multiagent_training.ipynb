# %% [markdown]
# # Asynchronous Multiagent Decision Making
# This tutorial demonstrates how to configure and train a multiagent environment in RLlib
# in which homogeneous agents act asyncronously while learning learning a single policy.
#
# <div class="alert alert-warning">
#
# **Warning:** Part of RLlib's backend mishandles the potential for zero-length episodes,
# which this method may produce. If this PR is unmerged, it must be manually applied to your
# installation: https://github.com/ray-project/ray/pull/46721
#
# </div>
#
# This example was run with the following version of RLlib:

# %%
from importlib.metadata import version
version("ray")  # Parent package of RLlib
# Out:
# '2.35.0'

# %% [markdown]
# ## Define the Environment
# A simple multi-satellite environment is defined. This environment is trivial for the
# multiagent case since there is no communication or interaction between satellites, but it
# serves to demonstrate asynchronous behavior.

# %%
import numpy as np
from bsk_rl import act, data, obs, sats, scene
from bsk_rl.sim import dyn, fsw

class ScanningDownlinkDynModel(dyn.ContinuousImagingDynModel, dyn.GroundStationDynModel):
    # Define some custom properties to be accessed in the state
    @property
    def instrument_pointing_error(self) -> float:
        r_BN_P_unit = self.r_BN_P/np.linalg.norm(self.r_BN_P) 
        c_hat_P = self.satellite.fsw.c_hat_P
        return np.arccos(np.dot(-r_BN_P_unit, c_hat_P))
    
    @property
    def solar_pointing_error(self) -> float:
        a = self.world.gravFactory.spiceObject.planetStateOutMsgs[
            self.world.sun_index
        ].read().PositionVector
        a_hat_N = a / np.linalg.norm(a)
        nHat_B = self.satellite.sat_args["nHat_B"]
        NB = np.transpose(self.BN)
        nHat_N = NB @ nHat_B
        return np.arccos(np.dot(nHat_N, a_hat_N))

class ScanningSatellite(sats.AccessSatellite):
    observation_spec = [
        obs.SatProperties(
            dict(prop="storage_level_fraction"),
            dict(prop="battery_charge_fraction"),
            dict(prop="wheel_speeds_fraction"),
            dict(prop="instrument_pointing_error", norm=np.pi),
            dict(prop="solar_pointing_error", norm=np.pi)
        ),
        obs.OpportunityProperties(
            dict(prop="opportunity_open", norm=5700),
            dict(prop="opportunity_close", norm=5700),
            type="ground_station",
            n_ahead_observe=1,
        ),
        obs.Eclipse(norm=5700),
    ]
    action_spec = [
        act.Scan(duration=150.0),
        act.Charge(duration=120.0),
        act.Downlink(duration=80.0),
        act.Desat(duration=45.0),
    ]
    dyn_type = ScanningDownlinkDynModel
    fsw_type = fsw.ContinuousImagingFSWModel

sats = [ScanningSatellite(
    f"Scanner-{i+1}",
    sat_args=dict(
        # Data
        dataStorageCapacity=5000 * 8e6,  # bits
        storageInit=lambda: np.random.uniform(0.0, 0.8) * 5000 * 8e6,
        instrumentBaudRate=0.5 * 8e6,
        transmitterBaudRate=-50 * 8e6,
        # Power
        batteryStorageCapacity=200 * 3600,  # W*s
        storedCharge_Init=lambda: np.random.uniform(0.3, 1.0) * 200 * 3600,
        basePowerDraw=-10.0,  # W
        instrumentPowerDraw=-30.0,  # W
        transmitterPowerDraw=-25.0,  # W
        thrusterPowerDraw=-80.0,  # W
        panelArea=0.25,
        # Attitude
        imageAttErrorRequirement=0.1,
        imageRateErrorRequirement=0.1,
        disturbance_vector=lambda: np.random.normal(scale=0.0001, size=3),  # N*m
        maxWheelSpeed=6000.0,  # RPM
        wheelSpeeds=lambda: np.random.uniform(-3000, 3000, 3),
        desatAttitude="nadir",
    )
) for i in range(4)]

# %% [markdown]
# ### Correlated Environment Parameters
# To construct a constellation with some coordinated, a function is generated to map satellites
# to orbital elements:

# %%
from bsk_rl.utils.orbital import walker_delta_args

sat_arg_randomizer = walker_delta_args(n_planes=2, altitude=500)

# %% [markdown]
# The `sat_arg_randomizer` is included in the environment arguments.

# %%
duration = 5 * 5700.0  # About 5 orbits
env_args = dict(
    satellites=sats,
    scenario=scene.UniformNadirScanning(value_per_second=1/duration),
    rewarder=data.ScanningTimeReward(),
    time_limit=duration,
    failure_penalty=-1.0,
    terminate_on_time_limit=True,
    sat_arg_randomizer=sat_arg_randomizer,
)

# %% [markdown]
# ## RLlib Training Configuration
#
# A standard PPO configuration is generated.

# %%
import bsk_rl.utils.rllib  # noqa To access "ConstellationTasking-RLlib"
from ray.rllib.algorithms.ppo import PPOConfig


N_CPUS = 3

training_args = dict(
    lr=0.00003,
    gamma=0.99997,
    train_batch_size=200 * N_CPUS,
    num_sgd_iter=10,
    lambda_=0.95,
    use_kl_loss=False,
    clip_param=0.1,
    grad_clip=0.5,
    mini_batch_size_per_learner=100,
)

config = (
    PPOConfig()
    .environment(
        "ConstellationTasking-RLlib",
        env_config=env_args,
    )
    .env_runners(
        num_env_runners=N_CPUS - 1,
        sample_timeout_s=1000.0,
    )
    .reporting(
        metrics_num_episodes_for_smoothing=1,
        metrics_episode_collection_timeout_s=180,
    )
    .checkpointing(export_native_model_files=True)
    .framework(framework="torch")
    .api_stack(
        enable_rl_module_and_learner=True,
        enable_env_runner_and_connector_v2=True,
    )
    .training(
        **training_args,
    )
)

# %% [markdown]
# To set up multiple agents using the same policy, the following configurations are set to
# map all agents to the policy `p0`.

# %%
try:
    from ray.rllib.core.rl_module.multi_rl_module import MultiRLModuleSpec
    from ray.rllib.core.rl_module.rl_module import RLModuleSpec
except (ImportError, ModuleNotFoundError):  # Older versions of RLlib
    from ray.rllib.core.rl_module.marl_module import (
        MultiAgentRLModuleSpec as MultiRLModuleSpec,
    )
    from ray.rllib.core.rl_module.rl_module import (
        SingleAgentRLModuleSpec as RLModuleSpec,
    )

config.multi_agent(
    policies={"p0"},
    policy_mapping_fn=lambda *args, **kwargs: "p0",
).rl_module(
    model_config_dict={
        "use_lstm": False,
        # Use a simpler FCNet when we also have an LSTM.
        "fcnet_hiddens": [2048, 2048],
        "vf_share_layers": False,
    },
    rl_module_spec=MultiRLModuleSpec(
        module_specs={
            "p0": RLModuleSpec(),
        }
    ),
)

# %% [markdown]
# ### Configuring Multiagent Logging Callbacks
# A callback function for the entire environment

# %%
def env_metrics_callback(env):
    reward = env.rewarder.cum_reward
    reward = sum(reward.values()) / len(reward)
    return dict(reward=reward)

# %% [markdown]
# and per satellite

# %%
def sat_metrics_callback(env, satellite):
    data = dict(
        # Are satellites dying, and how and when?
        alive=float(satellite.is_alive()),
        rw_status_valid=float(satellite.dynamics.rw_speeds_valid()),
        battery_status_valid=float(satellite.dynamics.battery_valid()),
    )
    return data

# %% [markdown]
# are defined. The `sat_metrics_callback` will be reported per-agent and as a mean. If
# using the predefined `"ConstellationTasking-RLlib"`, only the `WrappedEpisodeDataCallbacks`
# need to be added to the config, as in the single-agent case.

# %%
from bsk_rl.utils.rllib.callbacks import WrappedEpisodeDataCallbacks

config.callbacks(WrappedEpisodeDataCallbacks)

# %% [markdown]
# ### Action Continuation and Concatenation
# Logic to prevent all agents from retasking whenever any agent finishes an action
# is introduced, in the form of connector modules. First, the `ContinuePreviousAction` connector
# overrides any policy-selected action with the `bsk_rl.NO_ACTION` whenever `requires_retasking==False`
# for an agent, causing the agent to continue its current action.

# %%
from bsk_rl.utils.rllib import discounting

config.env_runners(
    module_to_env_connector=lambda env: (discounting.ContinuePreviousAction(),)
)

# %% [markdown]
# Then, two other connectors compress `NO_ACTION` out of episodes of experience, combining
# steps into those with super-actions. The `d_ts` timestep flag is calculated accordingly.

# %%
config.training(
    learner_connector=lambda obs_space, act_space: (
        discounting.MakeAddedStepActionValid(expected_train_batch_size=config.train_batch_size),
        discounting.CondenseMultiStepActions(),
    ),
)

# %% [markdown]
# Lastly, the `TimeDiscountedGAEPPOTorchLearner` is used, as in :doc:`examples/time_discounted_gae`.

# %%
config.training(learner_class=discounting.TimeDiscountedGAEPPOTorchLearner)

# %% [markdown]
# Note that when using these connectors, only the `requires_retasking` flag will case agents
# to select a new action. Step timeouts due to `max_step_duration` will not trigger retasking.

# %% [markdown]
# ## Training the Agent
# At this point, the PPO config can be trained as desired.

# %%
import ray
from ray import tune

ray.init(
    ignore_reinit_error=True,
    num_cpus=N_CPUS,
    object_store_memory=2_000_000_000,  # 2 GB
)

# Run the training
tune.run(
    "PPO",
    config=config.to_dict(),
    stop={"training_iteration": 2},  # Adjust the number of iterations as needed
)

# Shutdown Ray
ray.shutdown()
# Out:
# 2026-05-19 20:27:32,507	INFO worker.py:1783 -- Started a local Ray instance.
# 2026-05-19 20:27:35,713	INFO tune.py:616 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages/gymnasium/spaces/box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float32
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages/gymnasium/utils/passive_env_checker.py:164: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# /opt/hostedtoolcache/Python/3.11.15/x64/lib/python3.11/site-packages/gymnasium/utils/passive_env_checker.py:188: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2026-05-19 20:28:15</td></tr>
# <tr><td>Running for: </td><td>00:00:39.38        </td></tr>
# <tr><td>Memory:      </td><td>5.0/15.6 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 3.0/3 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                                </th><th>status    </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">     num_env_steps_sample
# d_lifetime</th><th style="text-align: right;">  num_episodes_lifetim
# e</th><th style="text-align: right;">     num_env_steps_traine
# d_lifetime</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_ConstellationTasking-RLlib_2c094_00000</td><td>TERMINATED</td><td>10.1.0.241:2925</td><td style="text-align: right;">     2</td><td style="text-align: right;">         24.0727</td><td style="text-align: right;">1200</td><td style="text-align: right;">1</td><td style="text-align: right;">1200</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# (PPO pid=2925) Install gputil for GPU system monitoring.
# (MultiAgentEnvRunner pid=2976) 2026-05-19 20:27:55,002 sats.satellite.Scanner-4       WARNING    <5925.00> Scanner-4: failed battery_valid check
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name                                </th><th>env_runners                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 </th><th>fault_tolerance                                                                           </th><th>learners                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    </th><th>num_agent_steps_sampled_lifetime                                           </th><th style="text-align: right;">  num_env_steps_sampled_lifetime</th><th style="text-align: right;">  num_env_steps_trained_lifetime</th><th style="text-align: right;">  num_episodes_lifetime</th><th>perf                                                                                                  </th><th>timers                                                                                                                                                                          </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_ConstellationTasking-RLlib_2c094_00000</td><td>{&#x27;num_env_steps_sampled&#x27;: 600, &#x27;num_module_steps_sampled_lifetime&#x27;: {&#x27;p0&#x27;: 6537}, &#x27;num_agent_steps_sampled&#x27;: {&#x27;Scanner-2&#x27;: 512, &#x27;Scanner-4&#x27;: 502, &#x27;Scanner-3&#x27;: 600, &#x27;Scanner-1&#x27;: 295}, &#x27;num_module_steps_sampled&#x27;: {&#x27;p0&#x27;: 1909}, &#x27;num_agent_steps_sampled_lifetime&#x27;: {&#x27;Scanner-3&#x27;: 1800, &#x27;Scanner-1&#x27;: 1495, &#x27;Scanner-4&#x27;: 1530, &#x27;Scanner-2&#x27;: 1712}, &#x27;num_env_steps_sampled_lifetime&#x27;: 2400, &#x27;num_episodes&#x27;: 1, &#x27;agent_episode_returns_mean&#x27;: {&#x27;Scanner-1&#x27;: -0.8559649122807016, &#x27;Scanner-4&#x27;: -0.9390877192982456, &#x27;Scanner-2&#x27;: -0.8777894736842105, &#x27;Scanner-3&#x27;: -0.8664912280701754}, &#x27;episode_duration_sec_mean&#x27;: 7.093417890000012, &#x27;episode_return_max&#x27;: -3.539333333333333, &#x27;agent_steps&#x27;: {&#x27;Scanner-1&#x27;: 365.0, &#x27;Scanner-4&#x27;: 214.0, &#x27;Scanner-2&#x27;: 347.0, &#x27;Scanner-3&#x27;: 398.0}, &#x27;episode_len_max&#x27;: 398, &#x27;module_episode_returns_mean&#x27;: {&#x27;p0&#x27;: -1.5803508771929822}, &#x27;episode_return_min&#x27;: -3.539333333333333, &#x27;episode_len_min&#x27;: 398, &#x27;episode_return_mean&#x27;: -3.539333333333333, &#x27;episode_len_mean&#x27;: 398.0}</td><td>{&#x27;num_healthy_workers&#x27;: 2, &#x27;num_in_flight_async_reqs&#x27;: 0, &#x27;num_remote_worker_restarts&#x27;: 0}</td><td>{&#x27;p0&#x27;: {&#x27;num_module_steps_trained&#x27;: 641, &#x27;vf_loss_unclipped&#x27;: 0.0031390043441206217, &#x27;num_non_trainable_parameters&#x27;: 0.0, &#x27;total_loss&#x27;: -0.477252721786499, &#x27;vf_loss&#x27;: 0.0031390043441206217, &#x27;default_optimizer_learning_rate&#x27;: 3e-05, &#x27;mean_kl_loss&#x27;: 0.0, &#x27;policy_loss&#x27;: -0.4803916811943054, &#x27;curr_entropy_coeff&#x27;: 0.0, &#x27;vf_explained_var&#x27;: -1.0, &#x27;gradients_default_optimizer_global_norm&#x27;: 0.7515062689781189, &#x27;num_trainable_parameters&#x27;: 8452101.0, &#x27;entropy&#x27;: 1.383366584777832}, &#x27;__all_modules__&#x27;: {&#x27;num_trainable_parameters&#x27;: 8452101.0, &#x27;num_env_steps_trained&#x27;: 600, &#x27;num_module_steps_trained&#x27;: 641, &#x27;num_non_trainable_parameters&#x27;: 0.0, &#x27;total_loss&#x27;: -0.477252721786499}}</td><td>{&#x27;Scanner-1&#x27;: 895, &#x27;Scanner-2&#x27;: 1112, &#x27;Scanner-3&#x27;: 1200, &#x27;Scanner-4&#x27;: 1016}</td><td style="text-align: right;">                            1200</td><td style="text-align: right;">                            1200</td><td style="text-align: right;">                      1</td><td>{&#x27;cpu_util_percent&#x27;: np.float64(36.39444444444444), &#x27;ram_util_percent&#x27;: np.float64(32.24444444444444)}</td><td>{&#x27;env_runner_sampling_timer&#x27;: 5.532510987259996, &#x27;learner_update_timer&#x27;: 6.187385482339991, &#x27;synch_weights&#x27;: 0.019775637969989362, &#x27;synch_env_connectors&#x27;: 0.006319646170001363}</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# (MultiAgentEnvRunner pid=2975) 2026-05-19 20:28:03,265 sats.satellite.Scanner-1       WARNING    <8725.00> Scanner-1: failed battery_valid check
# (MultiAgentEnvRunner pid=2976) 2026-05-19 20:28:03,551 sats.satellite.Scanner-2       WARNING    <10205.00> Scanner-2: failed battery_valid check
# (MultiAgentEnvRunner pid=2976) 2026-05-19 20:28:03,819 sats.satellite.Scanner-1       WARNING    <11055.00> Scanner-1: failed battery_valid check
# (MultiAgentEnvRunner pid=2976) 2026-05-19 20:28:04,653 sats.satellite.Scanner-3       WARNING    <14685.00> Scanner-3: failed battery_valid check
# 2026-05-19 20:28:15,166	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/home/runner/ray_results/PPO_2026-05-19_20-27-35' in 0.0611s.
# 2026-05-19 20:28:15,447	INFO tune.py:1041 -- Total run time: 39.73 seconds (39.31 seconds for the tuning loop).
# (MultiAgentEnvRunner pid=2975) 2026-05-19 20:28:07,023 sats.satellite.Scanner-2       WARNING    <16780.00> Scanner-2: failed battery_valid check
